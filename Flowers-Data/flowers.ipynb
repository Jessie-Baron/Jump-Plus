# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import numpy

# %%
df = pd.read_csv('./Iris_1.csv')
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_new = df.where(df['SepalWidthCm'] > 4)
df_new
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   NaN            NaN           NaN            NaN           NaN     NaN
# 1   NaN            NaN           NaN            NaN           NaN     NaN
# 2   NaN            NaN           NaN            NaN           NaN     NaN
# 3   NaN            NaN           NaN            NaN           NaN     NaN
# 4   NaN            NaN           NaN            NaN           NaN     NaN
# ..   ..            ...           ...            ...           ...     ...
# 145 NaN            NaN           NaN            NaN           NaN     NaN
# 146 NaN            NaN           NaN            NaN           NaN     NaN
# 147 NaN            NaN           NaN            NaN           NaN     NaN
# 148 NaN            NaN           NaN            NaN           NaN     NaN
# 149 NaN            NaN           NaN            NaN           NaN     NaN
#
# [150 rows x 6 columns]

# %%
df_next = df.where(df['SepalWidthCm'] > 1)
df_next
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.where(df['SepalWidthCm'] > 2)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           0.2
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c='red')

# %%
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', data=df, hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>
